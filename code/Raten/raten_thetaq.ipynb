# %% [markdown]
# Imports und Weissemodell

# %%
#import sys
#sys.version
import modelbase
import modelbase.ratelaws as rl
from weisse import WeisseBaseModel, defaultParameters

import numpy as np
import matplotlib.pyplot as plt

# %%
cl = ['si','a','mr','mt','mm','mq', 'cr','ct','cm','cq','pr','pt','pm','pq']

# %%
thetaq = defaultParameters["thetaq"]
valuesOneHundredTimeSteps, valuesLastTimeStep, ratesvr, ratesvt, ratesvm, ratesvq = [], [], [], [], [], []

for _ in np.linspace(0,4,7):
    thetaq = thetaq - 0.5
    m = WeisseBaseModel({'thetaq':thetaq})
    print(thetaq)

    s = modelbase.Simulator(m)
    #                         ['si',       'a',     'mr',     'mt',   'mm',    'mq',    'cr', 'ct', 'cm', 'cq', 'pr',   'pt',    'pm',     'pq']
    weise_values = np.array([31096.192, 43297.502, 8514.558, 49.333, 49.333, 8811.960, 348.675, 0, 357.898, 0, 0.0414, 471.364, 471.364 , 471.364])
    changedValuesOverTimeArray = s.timeCourse(np.linspace(0,3000,100),weise_values);
    ratesvr.append(s.getRate('vr',r= None)) 
    ratesvt.append(s.getRate('vt',r= None))
    ratesvm.append(s.getRate('vm',r= None)) 
    ratesvq.append(s.getRate('vq',r= None)) 
    valuesOneHundredTimeSteps.append(changedValuesOverTimeArray)
# Out:
# Warning: overwriting keys ['thetaq']
# 3.88
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/integrate/_ode.py:1348: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self.messages.get(istate, unexpected_istate_msg)))
# Warning: overwriting keys ['thetaq']
# 3.38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-136bb75dc322> in <module>
#      10     #                         ['si',       'a',     'mr',     'mt',   'mm',    'mq',    'cr', 'ct', 'cm', 'cq', 'pr',   'pt',    'pm',     'pq']
#      11     weise_values = np.array([31096.192, 43297.502, 8514.558, 49.333, 49.333, 8811.960, 348.675, 0, 357.898, 0, 0.0414, 471.364, 471.364 , 471.364])
# ---> 12     changedValuesOverTimeArray = s.timeCourse(np.linspace(0,3000,100),weise_values);
#      13     ratesvr.append(s.getRate('vr',r= None))
#      14     ratesvt.append(s.getRate('vt',r= None))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/simulate.py in timeCourse(self, Torig, y0, integrator, minstep, maxstep, nsteps)
#     291                                     minstep=minstep,
#     292                                     maxstep=maxstep,
# --> 293                                     nsteps=nsteps))
#     294             cnt += 1
#     295         if self.doesMonitor() and self.successful():
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/simulate.py in integrate(self, t, minstep, maxstep, nsteps)
#     231                 r._integrator.iwork[2] = -1
#     232             try:
# --> 233                 r.integrate(t)
#     234                 if r.successful():
#     235                     break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/integrate/_ode.py in integrate(self, t, step, relax)
#     430             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     431                                   self._y, self.t, t,
# --> 432                                   self.f_params, self.jac_params)
#     433         except SystemError:
#     434             # f2py issue with tuple returns, see ticket 1187.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/integrate/_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1341         args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1342                [jac, self.call_args[-1], f_params, 0, jac_params]
# -> 1343         y1, t, istate = self.runner(*args)
#    1344         self.istate = istate
#    1345         if istate < 0:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/simulate.py in dydt(t, y, m)
#      72         self.model = model
#      73         def dydt(t, y, m):
# ---> 74             return m.model(y, t, **kwargs)
#      75
#      76         self.dydt = dydt
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/model.py in model(self, y, t, **kwargs)
#     534         dydt = np.zeros(len(y))
#     535         kwargs.update({'t':t})
# --> 536         v = self.rates(y, **kwargs)
#     537         idx = self.cpdIds()
#     538         for rate,st in self.stoichiometries.items():
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/model.py in rates(self, y, **kwargs)
#     494             Dictionary of rate names as keys and rates as values
#     495         """
# --> 496         z = self.fullConcVec(y)
#     497         return {r:self.rateFn[r](z, **kwargs) for r in self.stoichiometries.keys()}
#     498
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/model.py in fullConcVec(self, z)
#     557         """
#     558         for ammod in self.algebraicModules.values():
# --> 559             zam = ammod['convert_func'](z)
#     560             z = np.hstack([z,zam])
#     561         return z
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/modelbase/model.py in _amwrapper(y)
#     605             if len(np.array(y).shape) == 1:
#     606                 cpdarg = y[sids]
# --> 607                 return convert_func(self.par,cpdarg)
#     608             else:
#     609                 cpdarg = y[:,sids]
#
# ~/Documents/Uni/Bachelor_Arbeit/Raten/weisse.py in stGrowth(par, y)
#     131
#     132         def stGrowth(par, y):
# --> 133             return np.array([y[0] * y[1:].sum() / par.M])
#     134         self.add_algebraicModule(stGrowth, 'lambda', ['gamma', 'cr', 'ct', 'cm', 'cq'], ['lambda'])
#     135
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
# Plotten Sie die zeitliche Entwicklung
plt.figure(figsize=(20,10))
plt.title('vr', size = 20)
plt.xlabel('time [s]', size = 20)
plt.ylabel('concentration [a.u.]', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)

for i, data in enumerate(ratesvr):
    plt.plot(s.getT(),ratesvr[i], label = 'pr')
#plt.legend(loc = 'lower right',prop = {'size': 20})

# %%
# Plotten Sie die zeitliche Entwicklung
plt.figure(figsize=(20,10))
plt.title('vt', size = 20)
plt.xlabel('time [s]', size = 20)
plt.ylabel('concentration [a.u.]', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)

for i, data in enumerate(ratesvt):
    plt.plot(s.getT(),ratesvt[i], label = 'pr')
#plt.legend(loc = 'lower right',prop = {'size': 20})

# %%
# Plotten Sie die zeitliche Entwicklung
plt.figure(figsize=(20,10))
plt.title('vm', size = 20)
plt.xlabel('time [s]', size = 20)
plt.ylabel('concentration [a.u.]', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)

for i, data in enumerate(ratesvm):
    plt.plot(s.getT(),ratesvm[i], label = 'pr')
#plt.legend(loc = 'lower right',prop = {'size': 20})

# %%
# Plotten Sie die zeitliche Entwicklung
plt.figure(figsize=(20,10))
plt.title('vq', size = 20)
plt.xlabel('time [s]', size = 20)
plt.ylabel('concentration [a.u.]', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)

for i, data in enumerate(ratesvq):
    plt.plot(s.getT(),ratesvq[i], label = 'pr')
#plt.legend(loc = 'lower right',prop = {'size': 20})

# %%
lastvalueratevr, lastvalueratevt, lastvalueratevm, lastvalueratevq = [], [], [], []
y = np.linspace(0,4,7)
fig, Plotlist = plt.subplots(4,1,figsize=(15,20))
Plotlist = Plotlist.ravel()

for i, data in enumerate(ratesvr):
    lastvalueratevr.append(ratesvr[i][-1])

    
for i, data in enumerate(ratesvt):
    lastvalueratevt.append(ratesvr[i][-1])

    
for i, data in enumerate(ratesvm):
    lastvalueratevm.append(ratesvr[i][-1])

    
for i, data in enumerate(ratesvq):
    lastvalueratevq.append(ratesvq[i][-1])
    
for i, data in enumerate(lastvalueratevr):
    Plotlist[0].plot(lastvalueratevr,y, label = 'pr')
Plotlist[0].set_title('vr')
Plotlist[0].set_xlabel('wachstumsrate')
Plotlist[0].set_ylabel('vr')


for i, data in enumerate(lastvalueratevt):
    Plotlist[1].plot(lastvalueratevt,y, label = 'pr')
Plotlist[1].set_title('vt')
Plotlist[1].set_xlabel('wachstumsrate')
Plotlist[1].set_ylabel('vt')


for i, data in enumerate(lastvalueratevm):
    Plotlist[2].plot(lastvalueratevm,y, label = 'pr')
Plotlist[2].set_title('vm')
Plotlist[2].set_xlabel('wachstumsrate')
Plotlist[2].set_ylabel('vm')


for i, data in enumerate(lastvalueratevq):
    Plotlist[3].plot(lastvalueratevq,y, label = 'pr')
Plotlist[3].set_title('vq')
Plotlist[3].set_xlabel('wachstumsrate')
Plotlist[3].set_ylabel('vq')
