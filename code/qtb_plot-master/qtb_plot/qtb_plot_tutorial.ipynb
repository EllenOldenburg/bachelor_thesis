# %%
import numpy as np
import matplotlib.pyplot as plt
import qtb_plot

# %% [markdown]
# You can set the plotting preferences for the whole script/notebook after importing matplotlib by calling

# %%
qtb_plot.set()

# %% [markdown]
# which will default to the "notebook" context.

# %%
qtb_plot.set("notebook")

# %% [markdown]
# The matplotlib prop cycle will go through 9 colors and 4 linestyles, giving you 32 different possible lines.
# Which of course you should never actually plot on one graph.

# %%
x = np.linspace(1,10,100)
for i in range(8*4):
    plt.plot(x,x+i,label=i)
plt.legend(bbox_to_anchor=[1.1,1])
plt.show()

# %% [raw]
# The other available contexts are "paper" and "talk"

# %%
qtb_plot.set("paper")

# %%
x = np.linspace(1,10,100)
for i in range(9):
    plt.plot(x,x*i,label=i)
plt.legend(bbox_to_anchor=[1.1,1])
plt.show()

# %%
qtb_plot.set("talk")

# %%
x = np.linspace(1,10,100)
for i in range(9):
    plt.plot(x,x*i,label=i)
plt.legend(bbox_to_anchor=[1.1,1])
plt.show()
